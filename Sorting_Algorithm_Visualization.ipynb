# %% [markdown]
# <a href="https://colab.research.google.com/github/khemingkapat/benchmark_sorting_algo/blob/main/Sorting_Algorithm_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/result2.csv")
df
# Out:
#            Algo     Test  TimeUsedMS        n   min   max  arg
# 0        bubble  descend       2.490   1047.0 -50.0  51.0  NaN
# 1        bubble  descend       8.412   1773.0 -96.0  63.0  NaN
# 2        bubble  descend    3923.707  33818.0 -27.0  57.0  NaN
# 3        bubble  descend     553.245  12678.0  -7.0  69.0  NaN
# 4        bubble  descend     103.643   5650.0 -57.0  37.0  NaN
# ...         ...      ...         ...      ...   ...   ...  ...
# 2395  selection   sorted     498.205  45804.0 -83.0  57.0  NaN
# 2396  selection   sorted      59.753  15703.0 -53.0  80.0  NaN
# 2397  selection   sorted      61.506  15308.0  -9.0  32.0  NaN
# 2398  selection   sorted      82.067  17902.0 -76.0  89.0  NaN
# 2399  selection   sorted     213.533  28205.0 -18.0  71.0  NaN
#
# [2400 rows x 7 columns]

# %%
# df = df.set_index(["Algo","Test"])
df
# Out:
#            Algo     Test  TimeUsedMS        n   min   max  arg
# 0        bubble  descend       2.490   1047.0 -50.0  51.0  NaN
# 1        bubble  descend       8.412   1773.0 -96.0  63.0  NaN
# 2        bubble  descend    3923.707  33818.0 -27.0  57.0  NaN
# 3        bubble  descend     553.245  12678.0  -7.0  69.0  NaN
# 4        bubble  descend     103.643   5650.0 -57.0  37.0  NaN
# ...         ...      ...         ...      ...   ...   ...  ...
# 2395  selection   sorted     498.205  45804.0 -83.0  57.0  NaN
# 2396  selection   sorted      59.753  15703.0 -53.0  80.0  NaN
# 2397  selection   sorted      61.506  15308.0  -9.0  32.0  NaN
# 2398  selection   sorted      82.067  17902.0 -76.0  89.0  NaN
# 2399  selection   sorted     213.533  28205.0 -18.0  71.0  NaN
#
# [2400 rows x 7 columns]

# %%
df.describe()
# Out:
#         TimeUsedMS             n          min          max         arg
# count  2400.000000   2400.000000  2400.000000  2400.000000  600.000000
# mean    587.831838  25677.062500   -52.885000    49.917500   46.810000
# std    1258.807138  14247.546795    28.938136    29.399079   16.242956
# min       0.004000    202.000000  -100.000000     0.000000   21.000000
# 25%       1.204000  13724.500000   -80.000000    25.000000   32.750000
# 50%      59.552500  25743.500000   -50.000000    49.000000   47.000000
# 75%     391.035250  38179.500000   -28.000000    75.000000   59.000000
# max    8332.727000  49716.000000    -1.000000   100.000000   79.000000

# %% [markdown]
# # Scatter Plot

# %%
import matplotlib.pyplot as plt
test = "normal"
idx_df = df.set_index(["Algo","Test"])
ax = idx_df.loc["bubble",test].plot(kind="scatter",x="n",y="TimeUsedMS",label="bubble",color="Blue")
idx_df.loc["insertion",test].plot.scatter(x="n",y="TimeUsedMS",label="insertion",ax=ax,color="Red")
idx_df.loc["selection",test].plot.scatter(x="n",y="TimeUsedMS",label="selection",ax=ax,color="Green")
idx_df.loc["merge",test].plot.scatter(x="n",y="TimeUsedMS",label="merge",ax=ax,color="Orange")
idx_df.loc["quick",test].plot.scatter(x="n",y="TimeUsedMS",label="quick",ax=ax,color="Grey")
idx_df.loc["flagged_bubble",test].plot.scatter(x="n",y="TimeUsedMS",label="flagged_bubble",ax=ax,color="Pink")
plt.title(f"Sorting Algorithms vs {test} cases")
plt.show()

# %%
import matplotlib.pyplot as plt
test = "descend"
idx_df = df.set_index(["Algo","Test"])
ax = idx_df.loc["bubble",test].plot(kind="scatter",x="n",y="TimeUsedMS",label="bubble",color="Blue")
idx_df.loc["insertion",test].plot.scatter(x="n",y="TimeUsedMS",label="insertion",ax=ax,color="Red")
idx_df.loc["selection",test].plot.scatter(x="n",y="TimeUsedMS",label="selection",ax=ax,color="Green")
idx_df.loc["merge",test].plot.scatter(x="n",y="TimeUsedMS",label="merge",ax=ax,color="Orange")
idx_df.loc["quick",test].plot.scatter(x="n",y="TimeUsedMS",label="quick",ax=ax,color="Grey")
idx_df.loc["flagged_bubble",test].plot.scatter(x="n",y="TimeUsedMS",label="flagged_bubble",ax=ax,color="Pink")
plt.title(f"Sorting Algorithms vs {test} cases")
plt.show()

# %%
import matplotlib.pyplot as plt
test = "partial"
idx_df = df.set_index(["Algo","Test"])
ax = idx_df.loc["bubble",test].plot(kind="scatter",x="n",y="TimeUsedMS",label="bubble",color="Blue")
idx_df.loc["insertion",test].plot.scatter(x="n",y="TimeUsedMS",label="insertion",ax=ax,color="Red")
idx_df.loc["selection",test].plot.scatter(x="n",y="TimeUsedMS",label="selection",ax=ax,color="Green")
idx_df.loc["merge",test].plot.scatter(x="n",y="TimeUsedMS",label="merge",ax=ax,color="Orange")
idx_df.loc["quick",test].plot.scatter(x="n",y="TimeUsedMS",label="quick",ax=ax,color="Grey")
idx_df.loc["flagged_bubble",test].plot.scatter(x="n",y="TimeUsedMS",label="flagged_bubble",ax=ax,color="Pink")
plt.title(f"Sorting Algorithms vs {test} cases")
plt.show()

# %%
import matplotlib.pyplot as plt
test = "sorted"
idx_df = df.set_index(["Algo","Test"])
ax = idx_df.loc["bubble",test].plot(kind="scatter",x="n",y="TimeUsedMS",label="bubble",color="Blue")
idx_df.loc["insertion",test].plot.scatter(x="n",y="TimeUsedMS",label="insertion",ax=ax,color="Red")
idx_df.loc["selection",test].plot.scatter(x="n",y="TimeUsedMS",label="selection",ax=ax,color="Green")
idx_df.loc["merge",test].plot.scatter(x="n",y="TimeUsedMS",label="merge",ax=ax,color="Orange")
idx_df.loc["quick",test].plot.scatter(x="n",y="TimeUsedMS",label="quick",ax=ax,color="Grey")
idx_df.loc["flagged_bubble",test].plot.scatter(x="n",y="TimeUsedMS",label="flagged_bubble",ax=ax,color="Pink")
plt.title(f"Sorting Algorithms vs {test} cases")
plt.show()

# %% [markdown]
# # Each Sort

# %%
algo = "bubble"
idx_df = df.set_index(["Algo","Test"])
ax = idx_df.loc[algo,"sorted"].plot(kind = "scatter",x="n",y="TimeUsedMS",label="sorted",color="Blue")
idx_df.loc[algo,"partial"].plot.scatter(x="n",y="TimeUsedMS",label="partial",ax=ax,color="Red")
idx_df.loc[algo,"normal"].plot.scatter(x="n",y="TimeUsedMS",label="normal",ax=ax,color="Green")
idx_df.loc[algo,"descend"].plot.scatter(x="n",y="TimeUsedMS",label="descend",ax=ax,color="Orange")
plt.title(f"{algo.capitalize()} Sort")
plt.show()

# %%
algo = "flagged_bubble"
idx_df = df.set_index(["Algo","Test"])
ax = idx_df.loc[algo,"sorted"].plot(kind = "scatter",x="n",y="TimeUsedMS",label="sorted",color="Blue")
idx_df.loc[algo,"partial"].plot.scatter(x="n",y="TimeUsedMS",label="partial",ax=ax,color="Red")
idx_df.loc[algo,"normal"].plot.scatter(x="n",y="TimeUsedMS",label="normal",ax=ax,color="Green")
idx_df.loc[algo,"descend"].plot.scatter(x="n",y="TimeUsedMS",label="descend",ax=ax,color="Orange")
plt.title(f"{algo.capitalize()} Sort")
plt.show()

# %%
algo = "insertion"
idx_df = df.set_index(["Algo","Test"])
ax = idx_df.loc[algo,"sorted"].plot(kind = "scatter",x="n",y="TimeUsedMS",label="sorted",color="Blue")
idx_df.loc[algo,"partial"].plot.scatter(x="n",y="TimeUsedMS",label="partial",ax=ax,color="Red")
idx_df.loc[algo,"normal"].plot.scatter(x="n",y="TimeUsedMS",label="normal",ax=ax,color="Green")
idx_df.loc[algo,"descend"].plot.scatter(x="n",y="TimeUsedMS",label="descend",ax=ax,color="Orange")
plt.title(f"{algo.capitalize()} Sort")
plt.show()

# %%
algo = "selection"
idx_df = df.set_index(["Algo","Test"])
ax = idx_df.loc[algo,"sorted"].plot(kind = "scatter",x="n",y="TimeUsedMS",label="sorted",color="Blue")
idx_df.loc[algo,"partial"].plot.scatter(x="n",y="TimeUsedMS",label="partial",ax=ax,color="Red")
idx_df.loc[algo,"normal"].plot.scatter(x="n",y="TimeUsedMS",label="normal",ax=ax,color="Green")
idx_df.loc[algo,"descend"].plot.scatter(x="n",y="TimeUsedMS",label="descend",ax=ax,color="Orange")
plt.title(f"{algo.capitalize()} Sort")
plt.show()

# %%
algo = "merge"
idx_df = df.set_index(["Algo","Test"])
ax = idx_df.loc[algo,"sorted"].plot(kind = "scatter",x="n",y="TimeUsedMS",label="sorted",color="Blue")
idx_df.loc[algo,"partial"].plot.scatter(x="n",y="TimeUsedMS",label="partial",ax=ax,color="Red")
idx_df.loc[algo,"normal"].plot.scatter(x="n",y="TimeUsedMS",label="normal",ax=ax,color="Green")
idx_df.loc[algo,"descend"].plot.scatter(x="n",y="TimeUsedMS",label="descend",ax=ax,color="Orange")
plt.title(f"{algo.capitalize()} Sort")
plt.show()

# %%
algo = "quick"
idx_df = df.set_index(["Algo","Test"])
ax = idx_df.loc[algo,"sorted"].plot(kind = "scatter",x="n",y="TimeUsedMS",label="sorted",color="Blue")
idx_df.loc[algo,"partial"].plot.scatter(x="n",y="TimeUsedMS",label="partial",ax=ax,color="Red")
idx_df.loc[algo,"normal"].plot.scatter(x="n",y="TimeUsedMS",label="normal",ax=ax,color="Green")
idx_df.loc[algo,"descend"].plot.scatter(x="n",y="TimeUsedMS",label="descend",ax=ax,color="Orange")
plt.title(f"{algo.capitalize()} Sort")
plt.show()

# %% [markdown]
# # Box Plot

# %%
import matplotlib.pyplot as plt
test = "normal"
ax = df.loc[df.Test == test].plot.box(column="TimeUsedMS",by="Algo",label="bubble",color="Blue")
plt.title(f"Time Used in Sorting Algorithm vs {test} cases")
plt.show()

# %%
import matplotlib.pyplot as plt
test = "descend"
ax = df.loc[df.Test == test].plot.box(column="TimeUsedMS",by="Algo",label="bubble",color="Blue")
plt.title(f"Time Used in Sorting Algorithm vs {test} cases")
plt.show()

# %%
import matplotlib.pyplot as plt
test = "partial"
ax = df.loc[df.Test == test].plot.box(column="TimeUsedMS",by="Algo",label="bubble",color="Blue")
plt.title(f"Time Used in Sorting Algorithm vs {test} cases")
plt.show()

# %%
import matplotlib.pyplot as plt
test = "sorted"
ax = df.loc[df.Test == test].plot.box(column="TimeUsedMS",by="Algo",label="bubble",color="Blue")
plt.title(f"Time Used in Sorting Algorithm vs {test} cases")
plt.show()
